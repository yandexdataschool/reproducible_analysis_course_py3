# %% [markdown]
# # OpenML in Python
# (Work in progress)
# Joaquin Vanschoren @joavanschoren

# %% [markdown]
# ## How to...
# - Download datasets and tasks
# - Use scikit-learn to build classifiers
# - Upload the results to the server

# %% [markdown]
# # Setup

# %% [markdown]
# ## Authentication
# Via API key (e.g. 'rgu9hw1h03g24j974hr3586g4j598fgh')
# Always keep it secret

# %% [markdown]
# Go to your OpenML account settings and see 'API authentication' to retrieve your key.
# <center><img src="files/openml_login.png" width="800"></center>

# %% [markdown]
# ## Installation
# Via source

# %%
#! git clone https://github.com/openml/openml-python.
#! cd openml-python
#! python setup.py install

# %% [markdown]
# ## Setup

# %%
from sklearn import preprocessing, ensemble

import openml
import numpy as np
import pandas as pd
import os

# assumes you have your api key in ~/.openml/config
# amueller's read/write key that he will throw away later
openml.config.apikey='ef035bbd1ca47af239c384aea9124ec5'
# Out:
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/utils/fixes.py:64: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if 'order' in inspect.getargspec(np.copy)[0]:

# %% [markdown]
# # Data

# %% [markdown]
# ## List ALL the datasets

# %%
datasets = openml.datasets.list_datasets()

data = pd.DataFrame(datasets)
print("First 10 of %s datasets..." % len(datasets))
print(data[:10][['did','name','NumberOfInstances','NumberOfFeatures']])
# Out:
# First 10 of 3349 datasets...
#    did             name  NumberOfInstances  NumberOfFeatures
# 0    1           anneal                898                39
# 1    2           anneal                898                39
# 2    3         kr-vs-kp               3196                37
# 3    4            labor                 57                17
# 4    5       arrhythmia                452               280
# 5    6           letter              20000                17
# 6    7        audiology                226                70
# 7    8  liver-disorders                345                 7
# 8    9            autos                205                26
# 9   10            lymph                148                19

# %% [markdown]
# Subset based on any property

# %%
bin_data = data.loc[data['NumberOfClasses'] == 2]
print("First 10 of %s datasets..." % len(bin_data))
print(bin_data[:10][['did','name', 'NumberOfInstances','NumberOfFeatures']])
# Out:
# First 10 of 738 datasets...
#     did            name  NumberOfInstances  NumberOfFeatures
# 2     3        kr-vs-kp               3196                37
# 3     4           labor                 57                17
# 12   13   breast-cancer                286                10
# 14   15        breast-w                699                10
# 23   24        mushroom               8124                23
# 24   25           colic                368                28
# 26   27           colic                368                23
# 28   29        credit-a                690                16
# 30   31        credit-g               1000                21
# 32   33  cylinder-bands                540                40

# %% [markdown]
# Subset based on any property

# %%
big_data = data.loc[data['NumberOfInstances'] > 60000]
big_data = big_data.sort_values(by='NumberOfInstances', ascending=True)
print("First 10 of %s datasets..." % len(bin_data))
print(big_data[:10][['did','name', 'NumberOfInstances']])
# Out:
# First 10 of 738 datasets...
#        did                          name  NumberOfInstances
# 1302  1588                           w8a              64700
# 2421  4533  KEGGMetabolicReactionNetwork              65554
# 1305  1591                     connect-4              67557
# 423    554                     mnist_784              70000
# 1293  1578                      real-sim              72309
# 1062  1213                       BNG(mv)              78732
# 2420  4532                         higgs              98050
# 247    357                vehicle_sensIT              98528
# 1080  1242                   vehicleNorm              98528
# 1307  1593       SensIT-Vehicle-Combined              98528

# %% [markdown]
# Download a specific dataset. This is done based on the dataset ID (called 'did' in the table above).

# %%
dataset = openml.datasets.get_dataset(61)

print("This is dataset '%s', the target feature is called '%s'" % (dataset.name, dataset.default_target_attribute))
print("URL: %s" % dataset.url)
print(dataset.description[:500])
# Out:
# This is dataset 'iris', the target feature is called 'class'
# URL: http://www.openml.org/data/download/61/dataset_61_iris.arff
# **Author**: R.A. Fisher
# **Source**: [UCI](https://archive.ics.uci.edu/ml/datasets/Iris) - 1936 - Donated by Michael Marshall
# **Please cite**:
#
# **Iris Plants Database**
# This is perhaps the best known database to be found in the pattern recognition literature.  Fisher's paper is a classic in the field and is referenced frequently to this day.  (See Duda & Hart, for example.)  The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class

# %%
from pprint import pprint
pprint(vars(dataset))
# Out:
# {'citation': None,
#  'collection_date': '1936',
#  'contributor': None,
#  'creator': 'R.A. Fisher',
#  'data_file': '/.openml/cache/datasets/61/dataset.arff',
#  'data_pickle_file': '/.openml/cache/datasets/61/dataset.pkl',
#  'default_target_attribute': 'class',
#  'description': '**Author**: R.A. Fisher  \n'
#                 '**Source**: '
#                 '[UCI](https://archive.ics.uci.edu/ml/datasets/Iris) - 1936 - '
#                 'Donated by Michael Marshall  \n'
#                 '**Please cite**:   \n'
#                 '\n'
#                 '**Iris Plants Database**  \n'
#                 'This is perhaps the best known database to be found in the '
#                 "pattern recognition literature.  Fisher's paper is a classic "
#                 'in the field and is referenced frequently to this day.  (See '
#                 'Duda & Hart, for example.)  The data set contains 3 classes '
#                 'of 50 instances each, where each class refers to a type of '
#                 'iris plant.  One class is     linearly separable from the '
#                 'other 2; the latter are NOT linearly separable from each '
#                 'other.\n'
#                 '\n'
#                 'Predicted attribute: class of iris plant.  \n'
#                 'This is an exceedingly simple domain.  \n'
#                 ' \n'
#                 '### Attribute Information:\n'
#                 '    1. sepal length in cm\n'
#                 '    2. sepal width in cm\n'
#                 '    3. petal length in cm\n'
#                 '    4. petal width in cm\n'
#                 '    5. class: \n'
#                 '       -- Iris Setosa\n'
#                 '       -- Iris Versicolour\n'
#                 '       -- Iris Virginica',
#  'format': 'ARFF',
#  'id': 61,
#  'ignore_attributes': None,
#  'language': None,
#  'licence': 'Public',
#  'md5_cheksum': '3a212cce13fc6f9b94f4793285813d95',
#  'name': 'iris',
#  'original_data_url': 'https://archive.ics.uci.edu/ml/datasets/Iris',
#  'paper_url': 'http://digital.library.adelaide.edu.au/dspace/handle/2440/15227',
#  'row_id_attribute': None,
#  'tag': ['study_1', 'study_4', 'study_7', 'uci'],
#  'update_comment': None,
#  'upload_date': '2014-04-06 23:23:39',
#  'url': 'http://www.openml.org/data/download/61/dataset_61_iris.arff',
#  'version': 1,
#  'version_label': '1',
#  'visibility': 'public'}

# %% [markdown]
# Get the actual data

# %%
X, y, attribute_names = dataset.get_dataset(target=dataset.default_target_attribute, return_attribute_names=True)
iris = pd.DataFrame(X, columns=attribute_names)
iris['class'] = y
print(iris[:10])
# Out:
#    sepallength  sepalwidth  petallength  petalwidth  class
# 0          5.1         3.5          1.4         0.2      0
# 1          4.9         3.0          1.4         0.2      0
# 2          4.7         3.2          1.3         0.2      0
# 3          4.6         3.1          1.5         0.2      0
# 4          5.0         3.6          1.4         0.2      0
# 5          5.4         3.9          1.7         0.4      0
# 6          4.6         3.4          1.4         0.3      0
# 7          5.0         3.4          1.5         0.2      0
# 8          4.4         2.9          1.4         0.2      0
# 9          4.9         3.1          1.5         0.1      0

# %% [markdown]
# Have fun with it

# %%
iris.plot(kind='scatter', x='petallength', y='petalwidth', c='class', s=50);
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-c23bd7343634> in <module>()
# ----> 1 iris.plot(kind='scatter', x='petallength', y='petalwidth', c='class', s=50);
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3665                           fontsize=fontsize, colormap=colormap, table=table,
#    3666                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3667                           sort_columns=sort_columns, **kwds)
#    3668     __call__.__doc__ = plot_frame.__doc__
#    3669
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/pandas/tools/plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2550                  yerr=yerr, xerr=xerr,
#    2551                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2552                  **kwds)
#    2553
#    2554
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2378         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2379
# -> 2380     plot_obj.generate()
#    2381     plot_obj.draw()
#    2382     return plot_obj.result
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/pandas/tools/plotting.py in generate(self)
#     982         self._args_adjust()
#     983         self._compute_plot_data()
# --> 984         self._setup_subplots()
#     985         self._make_plot()
#     986         self._add_table()
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/pandas/tools/plotting.py in _setup_subplots(self)
#    1033         else:
#    1034             if self.ax is None:
# -> 1035                 fig = self.plt.figure(figsize=self.figsize)
#    1036                 axes = fig.add_subplot(111)
#    1037             else:
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, **kwargs)
#     433                                         frameon=frameon,
#     434                                         FigureClass=FigureClass,
# --> 435                                         **kwargs)
#     436
#     437         if figLabel:
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/matplotlib/backends/backend_qt4agg.py in new_figure_manager(num, *args, **kwargs)
#      45     FigureClass = kwargs.pop('FigureClass', Figure)
#      46     thisFig = FigureClass(*args, **kwargs)
# ---> 47     return new_figure_manager_given_figure(num, thisFig)
#      48
#      49
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/matplotlib/backends/backend_qt4agg.py in new_figure_manager_given_figure(num, figure)
#      52     Create a new figure manager instance for the given figure.
#      53     """
# ---> 54     canvas = FigureCanvasQTAgg(figure)
#      55     return FigureManagerQT(canvas, num)
#      56
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/matplotlib/backends/backend_qt4agg.py in __init__(self, figure)
#      70         if DEBUG:
#      71             print('FigureCanvasQtAgg: ', figure)
# ---> 72         FigureCanvasQT.__init__(self, figure)
#      73         FigureCanvasAgg.__init__(self, figure)
#      74         self._drawRect = None
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/matplotlib/backends/backend_qt4.py in __init__(self, figure)
#      66         if DEBUG:
#      67             print('FigureCanvasQt qt4: ', figure)
# ---> 68         _create_qApp()
#      69
#      70         # Note different super-calling style to backend_qt5
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/matplotlib/backends/backend_qt5.py in _create_qApp()
#     136                 display = os.environ.get('DISPLAY')
#     137                 if display is None or not re.search(':\d', display):
# --> 138                     raise RuntimeError('Invalid DISPLAY variable')
#     139
#     140             qApp = QtWidgets.QApplication([str(" ")])
#
# RuntimeError: Invalid DISPLAY variable

# %% [markdown]
# Train a scikit-learn model on the data

# %%
dataset = openml.datasets.get_dataset(61)
X, y = dataset.get_dataset(target=dataset.default_target_attribute)
clf = ensemble.RandomForestClassifier()
clf.fit(X, y)
# Out:
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# Helper code by Gilles Louppe
# % matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

def plot_surface(clf, X, y, 
                 xlim=(0, 7), ylim=(0, 3), n_steps=250, 
                 subplot=None, show=True):
    if subplot is None:
        fig = plt.figure()
    else:
        plt.subplot(*subplot)
        
    xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], n_steps), 
                         np.linspace(ylim[0], ylim[1], n_steps))
    
    if hasattr(clf, "decision_function"):
        z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
    else:
        z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
        
    z = z.reshape(xx.shape)
    plt.contourf(xx, yy, z, alpha=0.8, cmap=plt.cm.RdBu_r)
    plt.scatter(X[:, 0], X[:, 1], c=y)
    plt.xlim(*xlim)
    plt.ylim(*ylim)
    
    if show:
        plt.show()

# %%
X_2d = X[:,2:4]
clf.fit(X_2d, y)
# %matplotlib inline
plot_surface(clf, X_2d, y)
# Out:
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# You can also ask which features are categorical to do your own encoding

# %%
X, y, categorical = dataset.get_dataset(target=dataset.default_target_attribute,return_categorical_indicator=True)
enc = preprocessing.OneHotEncoder(categorical_features=categorical)
X = enc.fit_transform(X)
clf.fit(X, y)
# Out:
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# # Tasks

# %% [markdown]
# To run benchmarks consistently (also across studies and tools), OpenML offers Tasks, which include specific train-test splits and other information.

# %% [markdown]
# ## List ALL the tasks

# %%
task_list = openml.tasks.list_tasks()

tasks = pd.DataFrame(task_list)
print("First 5 of %s tasks:" % len(tasks))
print(tasks[:5][['tid','did','name','task_type','estimation_procedure']])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-19-7653a7076e49> in <module>()
# ----> 1 task_list = openml.tasks.list_tasks()
#       2
#       3 tasks = pd.DataFrame(task_list)
#       4 print("First 5 of %s tasks:" % len(tasks))
#       5 print(tasks[:5][['tid','did','name','task_type','estimation_procedure']])
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/openml/tasks/task_functions.py in list_tasks()
#     136         the associated dataset, some of these are also returned.
#     137     """
# --> 138     return _list_tasks('task/list')
#     139
#     140
#
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/openml/tasks/task_functions.py in _list_tasks(api_call)
#     174                 task[input['@name']] = value
#     175
# --> 176         task[input['@name']] = input['#text']
#     177
#     178         # The number of qualities can range from 0 to infinity
#
# UnboundLocalError: local variable 'input' referenced before assignment

# %% [markdown]
# ## Download tasks

# %%
task = openml.tasks.get_task(10)
print(task)
# Out:
# OpenMLTask instance.
# Task ID: 10
# Task type: Supervised Classification
# Dataset id: 10

# %% [markdown]
# # Runs

# %% [markdown]
# Run a scikit-learn classifier on the task (using the right splits)

# %%
from openml.runs import run_task

clf = ensemble.RandomForestClassifier()
run = run_task(task, clf)
print("RandomForest has run on the task.")
# Out:
# 2638
# RandomForest has run on the task.
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# ...
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)

# %% [markdown]
# Upload the run to the OpenML server

# %%
import xmltodict

return_code, response = run.publish()

if(return_code == 200):
    response_dict = xmltodict.parse(response)
    run_id = response_dict['oml:upload_run']['oml:run_id']
    print("Uploaded run with id %s" % (run_id))
    print("Check it at www.openml.org/r/%s" % (run_id))
# Out:
# /opt/conda/envs/open-ml/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# Uploaded run with id 538171
# Check it at www.openml.org/r/538171

# %% [markdown]
# More to come soon...
